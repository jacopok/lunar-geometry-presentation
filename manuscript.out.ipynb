# %% [markdown]
# # Project
#
# Jacopo Tissino
# May 20, 2026

# %% [markdown]
# This is some example text.

# %%
from IPython.display import Markdown

x = 1

Markdown(f'This is some Markdown rendered text with a variable ${x=}$.')
